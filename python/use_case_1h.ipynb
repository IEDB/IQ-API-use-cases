# %% [markdown]
# # IEDB Query API (IQ-API) - Use Case 1H
# **Goal**: Search for linear T cell epitopes arising from human proteins, restricted by HLA-A*02:01 that were tested in healthy individuals.

# %% [markdown]
# The goal of this use case is to query for T cell epitopes arising from human proteins, restricted by HLA-A*02:01 that were tested in healthy individuals.
#
# For more information on the expressive syntax of PostgresT, refer to [this document](https://postgrest.org/en/stable/api.html#).  For more details on the tables that are part of the API, refer to [the swagger documetation](http://query-api.iedb.org/docs/swagger/).
#
# ---

# %% [markdown]
# First, let's import required modules, set some globals, and define a function to print the corresponding CURL command for each request.  I've tried to include that CURL command for each example so that you can copy/paste it into your terminal.  You may want to pipe the output to a tool like 'jq' to have it render neatly.

# %%
import requests
import json
import time
import pandas as pd
from io import StringIO

base_uri='https://query-api.iedb.org'

# funciton to print the CURL command given a request
def print_curl_cmd(req):
    url = req.url
    print("curl -X 'GET' '" + url + "'")
# Out:
# /Users/jgbaum/.pyenv/versions/3.8.2/envs/jupyter/lib/python3.8/site-packages/pandas/compat/__init__.py:120: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %% [markdown]
# This may or may not have resulted in a warning about lzma compression.  That can be safely ignored...

# %% [markdown]
# ## Querying the epitope table
#
# First, let's try querying for all epitopes matching this search (457 as of Oct 15, 2021) by querying only the epitope_search table.

# %%
search_params={ 'structure_type': 'eq.Linear peptide',
                'tcell_ids': 'not.is.null',
                'mhc_allele_names': 'cs.{HLA-A*02:01}',
                'host_organism_iris': 'cs.{NCBITaxon:9606}',
                'source_organism_iris': 'cs.{NCBITaxon:9606}',
                'disease_names': 'cs.{healthy}',
                'order': 'structure_iri',
              }
table_name='epitope_search'
full_url=base_uri + '/' + table_name
result = requests.get(full_url, params=search_params)
print_curl_cmd(result)
# Out:
# curl -X 'GET' 'https://query-api.iedb.org/epitope_search?structure_type=eq.Linear+peptide&tcell_ids=not.is.null&mhc_allele_names=cs.%7BHLA-A%2A02%3A01%7D&host_organism_iris=cs.%7BNCBITaxon%3A9606%7D&source_organism_iris=cs.%7BNCBITaxon%3A9606%7D&disease_names=cs.%7Bhealthy%7D&order=structure_iri'

# %% [markdown]
# OK we have the result...now let's have a look.  **Note**: We are only printing the first record here to get a sense of what is returned.

# %%
print(json.dumps(result.json()[:1], indent=4))
# Out:
# [
#     {
#         "structure_id": 100725,
#         "structure_iri": "IEDB_EPITOPE:100725",
#         "structure_descriptions": [
#             "ALWMRLLPL"
#         ],
#         "curated_source_antigens": [
#             {
#                 "accession": "114318995",
#                 "name": "insulin [Homo sapiens]",
#                 "iri": "GENPEPT:114318995",
#                 "starting_position": 2,
#                 "ending_position": 10,
#                 "source_organism_name": "Homo sapiens (human)",
#                 "source_organism_iri": "NCBITaxon:9606"
#             },
#             {
#                 "accession": "ABI63346.1",
#                 "name": "insulin",
#                 "iri": "GENPEPT:ABI63346.1",
#                 "starting_position": 2,
#                 "ending_position": 10,
#                 "source_organism_name": "Homo sapiens (human)",
#                 "source_organism_iri": "NCBITaxon:9606"
#             },
#             {
#                 "accession": "NP_000198.1",
#                 "name": "proinsulin precursor",
#                 "iri": "GENPEPT:NP_000198.1",
#                 "starting_position": 2,
#                 "ending_position": 10,
#                 "source_organism_name": "Homo sapiens (human)",
#                 "source_organism_iri": "NCBITaxon:9606"
#             },
#             {
#                 "accession": "P01308.1",
#                 "name": "Insulin precursor",
#                 "iri": "UNIPROT:P01308.1",
#                 "starting_position": 2,
#                 "ending_position": 10,
#                 "source_organism_name": "Homo sapiens (human)",
#                 "source_organism_iri": "NCBITaxon:9606"
#             }
#         ],
#         "structure_type": "Linear peptide",
#         "linear_sequence": "ALWMRLLPL",
#         "e_modification": null,
#         "linear_sequence_length": 9,
#         "iedb_assay_ids": [
#             1605715,
#             1606246,
#             1617672,
#             1627631,
#             1627642,
#             1642235,
#             1643012,
#             1643711,
#             1643743,
#             1954138,
#             2103328,
#             2103329,
#             2396854,
#             2456212,
#             2456214,
#             3829683,
#             3829684,
#             5635215
#         ],
#         "iedb_assay_iris": [
#             "IEDB_ASSAY:1605715",
#             "IEDB_ASSAY:1606246",
#             "IEDB_ASSAY:1617672",
#             "IEDB_ASSAY:1627631",
#             "IEDB_ASSAY:1627642",
#             "IEDB_ASSAY:1642235",
#             "IEDB_ASSAY:1643012",
#             "IEDB_ASSAY:1643711",
#             "IEDB_ASSAY:1643743",
#             "IEDB_ASSAY:1954138",
#             "IEDB_ASSAY:2103328",
#             "IEDB_ASSAY:2103329",
#             "IEDB_ASSAY:2396854",
#             "IEDB_ASSAY:2456212",
#             "IEDB_ASSAY:2456214",
#             "IEDB_ASSAY:3829683",
#             "IEDB_ASSAY:3829684",
#             "IEDB_ASSAY:5635215"
#         ],
#         "reference_ids": [
#             1007442,
#             1007450,
#             1010840,
#             1014443,
#             1025099,
#             1027381,
#             1028764,
#             1028997,
#             1033071,
#             1035280
#         ],
#         "reference_iris": [
#             "IEDB_REFERENCE:1007442",
#             "IEDB_REFERENCE:1007450",
#             "IEDB_REFERENCE:1010840",
#             "IEDB_REFERENCE:1014443",
#             "IEDB_REFERENCE:1025099",
#             "IEDB_REFERENCE:1027381",
#             "IEDB_REFERENCE:1028764",
#             "IEDB_REFERENCE:1028997",
#             "IEDB_REFERENCE:1033071",
#             "IEDB_REFERENCE:1035280"
#         ],
#         "submission_ids": null,
#         "submission_iris": null,
#         "pdb_ids": null,
#         "chebi_ids": null,
#         "qualitative_measures": [
#             "Negative",
#             "Positive",
#             "Positive-High",
#             "Positive-Intermediate",
#             "Positive-Low"
#         ],
#         "mhc_allele_evidences": [
#             "Cited reference",
#             "Inferred by motif or alleles present",
#             "MHC binding assay",
#             "T cell assay -MHC subset identification"
#         ],
#         "antibody_isotypes": null,
#         "direct_ex_vivo_bool": 1,
#         "receptor_ids": null,
#         "receptor_group_ids": null,
#         "tcr_receptor_group_ids": null,
#         "bcr_receptor_group_ids": null,
#         "receptor_group_iris": null,
#         "tcr_receptor_group_iris": null,
#         "bcr_receptor_group_iris": null,
#         "receptor_types": null,
#         "receptor_names": null,
#         "receptor_chain1_types": null,
#         "receptor_chain2_types": null,
#         "receptor_chain1_full_seqs": null,
#         "receptor_chain2_full_seqs": null,
#         "receptor_chain1_cdr1_seqs": null,
#         "receptor_chain2_cdr1_seqs": null,
#         "receptor_chain1_cdr2_seqs": null,
#         "receptor_chain2_cdr2_seqs": null,
#         "receptor_chain1_cdr3_seqs": null,
#         "receptor_chain2_cdr3_seqs": null,
#         "host_organism_iri_search": [
#             "NCBITaxon:314295",
#             "NCBITaxon:40674",
#             "NCBITaxon:7742",
#             "NCBITaxon:9443",
#             "NCBITaxon:9606"
#         ],
#         "host_organism_iris": [
#             "NCBITaxon:9606"
#         ],
#         "host_organism_names": [
#             "Homo sapiens (human)"
#         ],
#         "source_organism_iri_search": [
#             "NCBITaxon:1",
#             "NCBITaxon:2759",
#             "NCBITaxon:314295",
#             "NCBITaxon:33208",
#             "NCBITaxon:40674",
#             "NCBITaxon:7742",
#             "NCBITaxon:9443",
#             "NCBITaxon:9606",
#             "OBI:0100026"
#         ],
#         "source_organism_iris": [
#             "NCBITaxon:9606"
#         ],
#         "source_organism_names": [
#             "Homo sapiens (human)"
#         ],
#         "mhc_allele_iri_search": [
#             "GO:0032991",
#             "GO:0042611",
#             "MRO:0000011",
#             "MRO:0001005",
#             "MRO:0001007",
#             "MRO:0001061",
#             "MRO:0001063",
#             "MRO:0001355",
#             "MRO:0001454",
#             "MRO:0001530",
#             "MRO:0001593",
#             "MRO:0001655",
#             "MRO:0001675"
#         ],
#         "mhc_allele_iris": [
#             "MRO:0001007",
#             "MRO:0001063",
#             "MRO:0001530",
#             "MRO:0001593"
#         ],
#         "mhc_allele_names": [
#             "HLA-A*02:01",
#             "HLA-A2",
#             "HLA-B*08:01",
#             "HLA-B8"
#         ],
#         "parent_source_antigen_iri_search": [
#             "BFO:0000040",
#             "PR:000000001",
#             "taxon_protein:2759",
#             "taxon_protein:314295",
#             "taxon_protein:33208",
#             "taxon_protein:40674",
#             "taxon_protein:7742",
#             "taxon_protein:9443",
#             "taxon_protein:9606",
#             "UNIPROT:A6XGL2",
#             "UNIPROT:P01308",
#             "UNIPROT:A6XGL2#SIPDFE1C7E17B5372F4",
#             "UNIPROT:P01308#SIP168E58835C8C217D"
#         ],
#         "parent_source_antigen_iris": [
#             "UNIPROT:A6XGL2",
#             "UNIPROT:P01308"
#         ],
#         "parent_source_antigen_names": [
#             "Insulin (UniProt:A6XGL2)",
#             "Insulin (UniProt:P01308)"
#         ],
#         "parent_source_antigen_source_org_iris": [
#             "NCBITaxon:9606"
#         ],
#         "parent_source_antigen_source_org_names": [
#             "Homo sapiens (human)"
#         ],
#         "disease_iri_search": [
#             "DOID:0014667",
#             "DOID:0050013",
#             "DOID:0060005",
#             "DOID:0060158",
#             "DOID:28",
#             "DOID:4",
#             "DOID:417",
#             "DOID:4194",
#             "DOID:7",
#             "DOID:9351",
#             "DOID:9744",
#             "ONTIE:0003423",
#             "ONTIE:0003542",
#             "ONTIE:0003543"
#         ],
#         "disease_iris": [
#             "DOID:9744",
#             "ONTIE:0003423"
#         ],
#         "disease_names": [
#             "healthy",
#             "type 1 diabetes mellitus"
#         ],
#         "assay_iri_search": [
#             "OBI:0001317",
#             "OBI:0001414",
#             "OBI:0001478",
#             "OBI:0001489",
#             "OBI:0001550",
#             "OBI:0001553",
#             "OBI:0001555",
#             "OBI:0001568",
#             "OBI:0001606",
#             "OBI:0001613",
#             "OBI:0001992",
#             "OBI:0002055",
#             "OBI:0002072",
#             "OBI:0002075",
#             "OBI:1110037",
#             "OBI:1110059",
#             "OBI:1110124",
#             "OBI:1110125",
#             "OBI:1110126",
#             "OBI:1110129",
#             "OBI:1110179"
#         ],
#         "assay_iris": [
#             "OBI:0001489",
#             "OBI:0001555",
#             "OBI:0001568",
#             "OBI:0001606",
#             "OBI:0001613",
#             "OBI:1110059",
#             "OBI:1110179"
#         ],
#         "assay_names": [
#             "half maximal inhibitory concentration (IC50)|purified MHC/competitive/fluorescence|nM",
#             "half maximal inhibitory concentration (IC50)|purified MHC/competitive/radioactivity|nM",
#             "IFNg release|ELISPOT",
#             "ligand presentation|cellular MHC/mass spectrometry",
#             "qualitative binding|cellular MHC/direct/fluorescence",
#             "qualitative binding|multimer/tetramer",
#             "qualitative binding|purified MHC"
#         ],
#         "non_peptidic_molecule_iri_search": null,
#         "non_peptidic_molecule_iris": null,
#         "non_peptidic_molecule_names": null,
#         "r_object_source_molecule_iri_search": null,
#         "r_object_source_molecule_iris": null,
#         "r_object_source_molecule_names": null,
#         "r_object_source_organism_iri_search": null,
#         "r_object_source_organism_iris": null,
#         "r_object_source_organism_names": null,
#         "mhc_classes": [
#             "I"
#         ],
#         "mhc_allele_resolutions": [
#             "2 chain",
#             "class"
#         ],
#         "e_related_object_types": null,
#         "tcell_ids": [
#             1606246,
#             1617672,
#             1627631,
#             1627642,
#             1642235,
#             1643012,
#             2103328,
#             2103329,
#             2396854,
#             2456212,
#             2456214
#         ],
#         "tcell_iris": [
#             "IEDB_ASSAY:1606246",
#             "IEDB_ASSAY:1617672",
#             "IEDB_ASSAY:1627631",
#             "IEDB_ASSAY:1627642",
#             "IEDB_ASSAY:1642235",
#             "IEDB_ASSAY:1643012",
#             "IEDB_ASSAY:2103328",
#             "IEDB_ASSAY:2103329",
#             "IEDB_ASSAY:2396854",
#             "IEDB_ASSAY:2456212",
#             "IEDB_ASSAY:2456214"
#         ],
#         "bcell_ids": null,
#         "bcell_iris": null,
#         "elution_ids": [
#             1605715,
#             1643711,
#             1643743,
#             1954138,
#             3829683,
#             3829684,
#             5635215
#         ],
#         "elution_iris": [
#             "IEDB_ASSAY:1605715",
#             "IEDB_ASSAY:1643711",
#             "IEDB_ASSAY:1643743",
#             "IEDB_ASSAY:1954138",
#             "IEDB_ASSAY:3829683",
#             "IEDB_ASSAY:3829684",
#             "IEDB_ASSAY:5635215"
#         ],
#         "journal_names": [
#             "BMC Immunol",
#             "Cell Metab",
#             "Clin Exp Immunol",
#             "Clin Immunol",
#             "Diabetes",
#             "Immunity",
#             "Tissue Antigens"
#         ],
#         "reference_types": [
#             "Literature"
#         ],
#         "pubmed_ids": [
#             "14617048",
#             "17065344",
#             "17327428",
#             "18305140",
#             "19837003",
#             "22943201",
#             "25597827",
#             "25992863",
#             "29562882",
#             "30078552"
#         ],
#         "reference_titles": [
#             "CD8 T cell autoreactivity to preproinsulin epitopes with very low human leucocyte antigen class I binding affinity.",
#             "CD8+ T-cell responses identify beta-cell autoimmunity in human type 1 diabetes.",
#             "Clonal Deletion Prunes but Does Not Eliminate Self-Specific \u03b1\u03b2 CD8(+) T Lymphocytes.",
#             "Conventional and Neo-antigenic Peptides Presented by \u03b2 Cells Are Targeted by Circulating Na\u00efve CD8+ T Cells in Type 1 Diabetic and Healthy Donors.",
#             "Low HLA binding of diabetes-associated CD8+ T-cell epitopes is increased by post translational modifications.",
#             "Monitoring of antigen-specific CD8 T cells in patients with type 1 diabetes treated with antiCD3 monoclonal antibodies.",
#             "Novel strategy for identification of candidate cytotoxic T-cell epitopes from human preproinsulin.",
#             "Preproinsulin specific CD8+ T cells in subjects with latent autoimmune diabetes show lower frequency and different pathophysiological characteristics than those with type 1 diabetes.",
#             "Recognition of HLA class I-restricted beta-cell epitopes in type 1 diabetes.",
#             "The frequency and immunodominance of islet-specific CD8+ T-cell responses change after type 1 diabetes diagnosis and treatment."
#         ],
#         "reference_authors": [
#             "Emanuela Martinuzzi; Giulia Novelli; Matthieu Scotto; Philippe Blancou; Jean-Marie Bach; Lucy Chaillous; Graziella Bruno; Lucienne Chatenoud; Peter van Endert; Roberto Mallone",
#             "John Sidney; Jose Luis Vela; Dave Friedrich; Ravi Kolla; Matthias von Herrath; Johnna D Wesley; Alessandro Sette",
#             "J R F Abreu; S Martina; A A Verrijn Stuart; Y E Filli\u00e9; K L M C Franken; J W Drijfhout; B O Roep",
#             "L Chang; L Kjer-Nielsen; S Flynn; A G Brooks; S I Mannering; M C Honeyman; L C Harrison; J McCluskey; A W Purcell",
#             "Naresh Sachdeva; Mahinder Paul; Darshan Badal; Rajendra Kumar; Neenu Jacob; Devi Dayal; Anil Bhansali; Sunil Kumar Arora; Sanjay Kumar Bhadada",
#             "Qin Ouyang; Nathan E Standifer; Huilian Qin; Peter Gottlieb; C Bruce Verchere; Gerald T Nepom; Rusung Tan; Constadina Panagiotopoulos",
#             "Roberto Mallone; Emanuela Martinuzzi; Philippe Blancou; Giulia Novelli; Georgia Afonso; Manuel Dolz; Graziella Bruno; Lucy Chaillous; Lucienne Chatenoud; Jean-Marie Bach; Peter van Endert",
#             "Sergio Gonzalez-Duque; Marie Eliane Azoury; Maikel L Colli; Georgia Afonso; Jean-Valery Turatsinze; Laura Nigi; Ana Ines Lalanne; Guido Sebastiani; Alexia Carr\u00e9; Sheena Pinto; Slobodan Culina; No\u00e9mie Corcos; Marco Bugliani; Piero Marchetti; Mathieu Armanet; Marc Diedisheim; Bruno Kyewski; Lars M Steinmetz; S\u00f8ren Buus; Sylvaine You; Daniele Dubois-Laforgue; Etienne Larger; Jean-Paul Beressi; Graziella Bruno; Francesco Dotta; Raphael Scharfmann; Decio L Eizirik; Yann Verdier; Joelle Vinh; Roberto Mallone",
#             "Simona Cernea; Kevan C Herold",
#             "Wong Yu; Ning Jiang; Peter J R Ebert; Brian A Kidd; Sabina M\u00fcller; Peder J Lund; Jeremy Juang; Keishi Adachi; Tiffany Tse; Michael E Birnbaum; Evan W Newell; Darrell M Wilson; Gijsbert M Grotenbreg; Salvatore Valitutti; Stephen R Quake; Mark M Davis"
#         ],
#         "reference_dates": [
#             "2003",
#             "2006",
#             "2007",
#             "2008",
#             "2010",
#             "2012",
#             "2015",
#             "2018"
#         ]
#     }
# ]

# %% [markdown]
# We can also load the output into a data frame.

# %%
df = pd.json_normalize(result.json())
df
# Out:
#      structure_id        structure_iri structure_descriptions  \
# 0          100725  IEDB_EPITOPE:100725            [ALWMRLLPL]
# 1          100843  IEDB_EPITOPE:100843            [FLFAVGFYL]
# 2          100844  IEDB_EPITOPE:100844            [FLIVLSVAL]
# 3          100845  IEDB_EPITOPE:100845            [FLWSVFMLI]
# 4          100882  IEDB_EPITOPE:100882           [GIVEQCCTSI]
# ..            ...                  ...                    ...
# 675        952989  IEDB_EPITOPE:952989            [YQMDIQQEL]
# 676        956443  IEDB_EPITOPE:956443            [RLARLALVL]
# 677         95972   IEDB_EPITOPE:95972            [VMAPRTVLL]
# 678        989936  IEDB_EPITOPE:989936            [KLQCVDLHV]
# 679         99044   IEDB_EPITOPE:99044            [VMAPRALLL]
#
#                                curated_source_antigens  structure_type  \
# 0    [{'accession': '114318995', 'name': 'insulin [...  Linear peptide
# 1    [{'accession': 'NP_066999.1', 'name': 'islet-s...  Linear peptide
# 2    [{'accession': 'CAA39504.1', 'name': 'IAPP [Ho...  Linear peptide
# 3    [{'accession': 'SRC244406', 'name': 'islet-spe...  Linear peptide
# 4    [{'accession': 'ABI63346.1', 'name': 'insulin'...  Linear peptide
# ..                                                 ...             ...
# 675  [{'accession': 'P04114.2', 'name': 'Apolipopro...  Linear peptide
# 676  [{'accession': 'Q13641.1', 'name': 'Trophoblas...  Linear peptide
# 677  [{'accession': '1465390624', 'name': 'MHC clas...  Linear peptide
# 678  [{'accession': 'AAA60193.1', 'name': 'prostate...  Linear peptide
# 679  [{'accession': 'BAA07531.1', 'name': 'HLA-Cw*0...  Linear peptide
#
#     linear_sequence e_modification  linear_sequence_length  \
# 0         ALWMRLLPL           None                       9
# 1         FLFAVGFYL           None                       9
# 2         FLIVLSVAL           None                       9
# 3         FLWSVFMLI           None                       9
# 4        GIVEQCCTSI           None                      10
# ..              ...            ...                     ...
# 675       YQMDIQQEL           None                       9
# 676       RLARLALVL           None                       9
# 677       VMAPRTVLL           None                       9
# 678       KLQCVDLHV           None                       9
# 679       VMAPRALLL           None                       9
#
#                                         iedb_assay_ids  \
# 0    [1605715, 1606246, 1617672, 1627631, 1627642, ...
# 1    [1605718, 1606254, 1617680, 1643063, 1643064, ...
# 2    [1605720, 1606253, 1617682, 1681501, 1681515, ...
# 3        [1605719, 1606255, 1617681, 3829713, 5564277]
# 4    [1617478, 1617485, 1617490, 1619777, 1621610, ...
# ..                                                 ...
# 675      [6352650, 6352814, 6352815, 6352824, 8571805]
# 676  [6352830, 6352831, 6352832, 6352833, 6352834, ...
# 677  [1588321, 1597906, 1647392, 1647393, 1770471, ...
# 678                                 [6376241, 8592283]
# 679  [1597580, 1618320, 1782839, 1782840, 1782855, ...
#
#                                        iedb_assay_iris  ... bcell_ids  \
# 0    [IEDB_ASSAY:1605715, IEDB_ASSAY:1606246, IEDB_...  ...      None
# 1    [IEDB_ASSAY:1605718, IEDB_ASSAY:1606254, IEDB_...  ...      None
# 2    [IEDB_ASSAY:1605720, IEDB_ASSAY:1606253, IEDB_...  ...      None
# 3    [IEDB_ASSAY:1605719, IEDB_ASSAY:1606255, IEDB_...  ...      None
# 4    [IEDB_ASSAY:1617478, IEDB_ASSAY:1617485, IEDB_...  ...      None
# ..                                                 ...  ...       ...
# 675  [IEDB_ASSAY:6352650, IEDB_ASSAY:6352814, IEDB_...  ...      None
# 676  [IEDB_ASSAY:6352830, IEDB_ASSAY:6352831, IEDB_...  ...      None
# 677  [IEDB_ASSAY:11103344, IEDB_ASSAY:11560295, IED...  ...      None
# 678           [IEDB_ASSAY:6376241, IEDB_ASSAY:8592283]  ...      None
# 679  [IEDB_ASSAY:11356632, IEDB_ASSAY:12464034, IED...  ...      None
#
#     bcell_iris                                        elution_ids  \
# 0         None  [1605715, 1643711, 1643743, 1954138, 3829683, ...
# 1         None               [1605718, 1643065, 1681498, 3829720]
# 2         None                        [1605720, 1681501, 3829711]
# 3         None                                 [1605719, 3829713]
# 4         None  [1617478, 1617490, 1639832, 1643772, 1762197, ...
# ..         ...                                                ...
# 675       None                                 [6352650, 8571805]
# 676       None                                          [6352837]
# 677       None  [1588321, 1597906, 1647392, 1647393, 1775259, ...
# 678       None                                          [8592283]
# 679       None  [1597580, 1782839, 1782840, 1782855, 1782856, ...
#
#                                           elution_iris  \
# 0    [IEDB_ASSAY:1605715, IEDB_ASSAY:1643711, IEDB_...
# 1    [IEDB_ASSAY:1605718, IEDB_ASSAY:1643065, IEDB_...
# 2    [IEDB_ASSAY:1605720, IEDB_ASSAY:1681501, IEDB_...
# 3             [IEDB_ASSAY:1605719, IEDB_ASSAY:3829713]
# 4    [IEDB_ASSAY:1617478, IEDB_ASSAY:1617490, IEDB_...
# ..                                                 ...
# 675           [IEDB_ASSAY:6352650, IEDB_ASSAY:8571805]
# 676                               [IEDB_ASSAY:6352837]
# 677  [IEDB_ASSAY:11103344, IEDB_ASSAY:11560295, IED...
# 678                               [IEDB_ASSAY:8592283]
# 679  [IEDB_ASSAY:11356632, IEDB_ASSAY:12464034, IED...
#
#                                          journal_names  \
# 0    [BMC Immunol, Cell Metab, Clin Exp Immunol, Cl...
# 1    [BMC Immunol, Clin Immunol, Diabetes, Diabetol...
# 2                              [BMC Immunol, Diabetes]
# 3              [BMC Immunol, Diabetes, Nat Biotechnol]
# 4    [Ann N Y Acad Sci, BMC Immunol, Clin Exp Immun...
# ..                                                 ...
# 675                        [Acta Neuropathol, Sci Rep]
# 676                        [Cancer Immunol Immunother]
# 677  [Acta Neuropathol, Anal Chem, Cancer Immunol I...
# 678                                 [Acta Neuropathol]
# 679  [Acta Neuropathol, Anal Chem, Hum Immunol, Imm...
#
#                           reference_types  \
# 0                            [Literature]
# 1                            [Literature]
# 2                            [Literature]
# 3                            [Literature]
# 4                            [Literature]
# ..                                    ...
# 675                          [Literature]
# 676                          [Literature]
# 677  [Dual, Literature, Live, Submission]
# 678              [Literature, Submission]
# 679  [Dual, Literature, Live, Submission]
#
#                                             pubmed_ids  \
# 0    [14617048, 17065344, 17327428, 18305140, 19837...
# 1    [17065343, 17065344, 18358785, 28887632, 29562...
# 2                       [17065343, 17065344, 29562882]
# 3                       [17065344, 29562882, 30418433]
# 4    [14617048, 15983206, 17130554, 17327428, 18390...
# ..                                                 ...
# 675                               [29557506, 31757993]
# 676                                         [31686124]
# 677  [11564797, 11920559, 12411439, 12461076, 20877...
# 678                                         [29557506]
# 679  [12411439, 15172443, 18339401, 22927436, 24714...
#
#                                       reference_titles  \
# 0    [CD8 T cell autoreactivity to preproinsulin ep...
# 1    [Identification of Novel HLA-A*0201-restricted...
# 2    [Identification of Novel HLA-A*0201-restricted...
# 3    [High-throughput determination of the antigen ...
# 4    [CD8 T cell autoreactivity to preproinsulin ep...
# ..                                                 ...
# 675  [Induction of HLA-A2 restricted CD8 T cell res...
# 676  [Preclinical development of T-cell receptor-en...
# 677  [A large fraction of HLA class I ligands are p...
# 678  [CD8+ T cells of Healthy Donors 1-4: Single Ce...
# 679  [A large peptidome dataset improves HLA class ...
#
#                                      reference_authors  \
# 0    [Emanuela Martinuzzi; Giulia Novelli; Matthieu...
# 1    [Irene Jarchum; Lynn Nichol; Massimo Trucco; P...
# 2    [John Sidney; Jose Luis Vela; Dave Friedrich; ...
# 3    [John Sidney; Jose Luis Vela; Dave Friedrich; ...
# 4    [Emmanuelle Enée; Emanuela Martinuzzi; Philipp...
# ..                                                 ...
# 675  [Frank H Schaftenaar; Jacob Amersfoort; Hidde ...
# 676  [Yuexin Xu; Alicia J Morales; Michael J Cargil...
# 677  [Ana Marcu; Leon Bichmann; Leon Kuchenbecker; ...
# 678  [10x Genomics, Marian Christoph Neidert; Danie...
# 679  [Alexander A Celik; Thomas Kraemer; Trevor Huy...
#
#                                        reference_dates
# 0     [2003, 2006, 2007, 2008, 2010, 2012, 2015, 2018]
# 1                             [2006, 2008, 2017, 2018]
# 2                                         [2006, 2018]
# 3                                         [2006, 2018]
# 4    [1996, 2003, 2005, 2006, 2007, 2008, 2010, 201...
# ..                                                 ...
# 675                                       [2018, 2019]
# 676                                             [2019]
# 677  [1997, 1998, 2001, 2002, 2003, 2010, 2012, 201...
# 678                                       [2018, 2020]
# 679  [2003, 2004, 2008, 2012, 2014, 2015, 2016, 201...
#
# [680 rows x 83 columns]

# %% [markdown]
# Alright, there are 680 records returned which is much more than we were expecting from performing this search through the web interface.  This is because some of these peptides were tested under all of the conditions that we specified, but not necessarily all in the same assay.  So, in order to do this correctly, we must first search on the tcell_search table to pull epitopes tested in a single assay that meets all of these conditions.
#
# ## Querying the tcell_search table
#
# Let's search for records that match all of these conditions in a single T cell assay:

# %%
search_params={ 'structure_type': 'eq.Linear peptide',
                'mhc_allele_name': 'eq.HLA-A*02:01',
                'host_organism_iri': 'eq.NCBITaxon:9606',
                'source_organism_iri': 'eq.NCBITaxon:9606',
                'disease_names': 'cs.{healthy}',
                'order': 'structure_iri',
              }
table_name='tcell_search'
full_url=base_uri + '/' + table_name
result = requests.get(full_url, params=search_params)
print_curl_cmd(result)
# Out:
# curl -X 'GET' 'https://query-api.iedb.org/tcell_search?structure_type=eq.Linear+peptide&mhc_allele_name=eq.HLA-A%2A02%3A01&host_organism_iri=eq.NCBITaxon%3A9606&source_organism_iri=eq.NCBITaxon%3A9606&disease_names=cs.%7Bhealthy%7D&order=structure_iri'

# %% [markdown]
# Let's take a peek at this result.

# %%
df = pd.json_normalize(result.json())
df
# Out:
#      tcell_id           tcell_iri  structure_id        structure_iri  \
# 0     2103329  IEDB_ASSAY:2103329        100725  IEDB_EPITOPE:100725
# 1     1617672  IEDB_ASSAY:1617672        100725  IEDB_EPITOPE:100725
# 2     1617680  IEDB_ASSAY:1617680        100843  IEDB_EPITOPE:100843
# 3     1617682  IEDB_ASSAY:1617682        100844  IEDB_EPITOPE:100844
# 4     1617681  IEDB_ASSAY:1617681        100845  IEDB_EPITOPE:100845
# ..        ...                 ...           ...                  ...
# 726   6354238  IEDB_ASSAY:6354238        956443  IEDB_EPITOPE:956443
# 727   6352834  IEDB_ASSAY:6352834        956443  IEDB_EPITOPE:956443
# 728   6352843  IEDB_ASSAY:6352843        956443  IEDB_EPITOPE:956443
# 729   6352847  IEDB_ASSAY:6352847        956443  IEDB_EPITOPE:956443
# 730   6352832  IEDB_ASSAY:6352832        956443  IEDB_EPITOPE:956443
#
#     linear_sequence  structure_type structure_description  reference_id  \
# 0         ALWMRLLPL  Linear peptide             ALWMRLLPL       1027381
# 1         ALWMRLLPL  Linear peptide             ALWMRLLPL       1007450
# 2         FLFAVGFYL  Linear peptide             FLFAVGFYL       1007450
# 3         FLIVLSVAL  Linear peptide             FLIVLSVAL       1007450
# 4         FLWSVFMLI  Linear peptide             FLWSVFMLI       1007450
# ..              ...             ...                   ...           ...
# 726       RLARLALVL  Linear peptide             RLARLALVL       1036010
# 727       RLARLALVL  Linear peptide             RLARLALVL       1036010
# 728       RLARLALVL  Linear peptide             RLARLALVL       1036010
# 729       RLARLALVL  Linear peptide             RLARLALVL       1036010
# 730       RLARLALVL  Linear peptide             RLARLALVL       1036010
#
#               reference_iri reference_type  ... r_object_source_organism_iri  \
# 0    IEDB_REFERENCE:1027381     Literature  ...                         None
# 1    IEDB_REFERENCE:1007450     Literature  ...                         None
# 2    IEDB_REFERENCE:1007450     Literature  ...                         None
# 3    IEDB_REFERENCE:1007450     Literature  ...                         None
# 4    IEDB_REFERENCE:1007450     Literature  ...                         None
# ..                      ...            ...  ...                          ...
# 726  IEDB_REFERENCE:1036010     Literature  ...                         None
# 727  IEDB_REFERENCE:1036010     Literature  ...                         None
# 728  IEDB_REFERENCE:1036010     Literature  ...                         None
# 729  IEDB_REFERENCE:1036010     Literature  ...                         None
# 730  IEDB_REFERENCE:1036010     Literature  ...                         None
#
#     r_object_source_organism_name e_related_object_type  \
# 0                            None                  None
# 1                            None                  None
# 2                            None                  None
# 3                            None                  None
# 4                            None                  None
# ..                            ...                   ...
# 726                          None                  None
# 727                          None                  None
# 728                          None                  None
# 729                          None                  None
# 730                          None                  None
#
#     curated_source_antigen.accession  \
# 0                        NP_000198.1
# 1                           P01308.1
# 2                        NP_066999.1
# 3                           P10997.1
# 4                          SRC244406
# ..                               ...
# 726                         Q13641.1
# 727                         Q13641.1
# 728                         Q13641.1
# 729                         Q13641.1
# 730                         Q13641.1
#
#                            curated_source_antigen.name  \
# 0                                 proinsulin precursor
# 1                                    Insulin precursor
# 2    islet-specific glucose-6-phosphatase-related p...
# 3                  Islet amyloid polypeptide precursor
# 4    islet-specific glucose-6-phosphatase-related p...
# ..                                                 ...
# 726                           Trophoblast glycoprotein
# 727                           Trophoblast glycoprotein
# 728                           Trophoblast glycoprotein
# 729                           Trophoblast glycoprotein
# 730                           Trophoblast glycoprotein
#
#     curated_source_antigen.iri curated_source_antigen.starting_position  \
# 0          GENPEPT:NP_000198.1                                      2.0
# 1             UNIPROT:P01308.1                                      2.0
# 2          GENPEPT:NP_066999.1                                    215.0
# 3             GENPEPT:P10997.1                                      9.0
# 4                ONTIE:0002097                                      NaN
# ..                         ...                                      ...
# 726           UNIPROT:Q13641.1                                     17.0
# 727           UNIPROT:Q13641.1                                     17.0
# 728           UNIPROT:Q13641.1                                     17.0
# 729           UNIPROT:Q13641.1                                     17.0
# 730           UNIPROT:Q13641.1                                     17.0
#
#     curated_source_antigen.ending_position  \
# 0                                     10.0
# 1                                     10.0
# 2                                    223.0
# 3                                     17.0
# 4                                      NaN
# ..                                     ...
# 726                                   25.0
# 727                                   25.0
# 728                                   25.0
# 729                                   25.0
# 730                                   25.0
#
#     curated_source_antigen.source_organism_name  \
# 0                          Homo sapiens (human)
# 1                          Homo sapiens (human)
# 2                          Homo sapiens (human)
# 3                          Homo sapiens (human)
# 4                          Homo sapiens (human)
# ..                                          ...
# 726                        Homo sapiens (human)
# 727                        Homo sapiens (human)
# 728                        Homo sapiens (human)
# 729                        Homo sapiens (human)
# 730                        Homo sapiens (human)
#
#     curated_source_antigen.source_organism_iri
# 0                               NCBITaxon:9606
# 1                               NCBITaxon:9606
# 2                               NCBITaxon:9606
# 3                               NCBITaxon:9606
# 4                               NCBITaxon:9606
# ..                                         ...
# 726                             NCBITaxon:9606
# 727                             NCBITaxon:9606
# 728                             NCBITaxon:9606
# 729                             NCBITaxon:9606
# 730                             NCBITaxon:9606
#
# [731 rows x 90 columns]

# %% [markdown]
# OK perfect, that matches the 731 assay records on the IEDB as of Oct 15 2021.  Now we just need to make this list unique by epitope.

# %%
df.drop_duplicates(subset = ['structure_iri'])
# Out:
#      tcell_id           tcell_iri  structure_id        structure_iri  \
# 0     2103329  IEDB_ASSAY:2103329        100725  IEDB_EPITOPE:100725
# 2     1617680  IEDB_ASSAY:1617680        100843  IEDB_EPITOPE:100843
# 3     1617682  IEDB_ASSAY:1617682        100844  IEDB_EPITOPE:100844
# 4     1617681  IEDB_ASSAY:1617681        100845  IEDB_EPITOPE:100845
# 5     2103326  IEDB_ASSAY:2103326        100882  IEDB_EPITOPE:100882
# ..        ...                 ...           ...                  ...
# 721   5635546  IEDB_ASSAY:5635546        952616  IEDB_EPITOPE:952616
# 722   6338160  IEDB_ASSAY:6338160        952620  IEDB_EPITOPE:952620
# 723   5635521  IEDB_ASSAY:5635521        952623  IEDB_EPITOPE:952623
# 724   5635523  IEDB_ASSAY:5635523        952624  IEDB_EPITOPE:952624
# 725   6352830  IEDB_ASSAY:6352830        956443  IEDB_EPITOPE:956443
#
#     linear_sequence  structure_type structure_description  reference_id  \
# 0         ALWMRLLPL  Linear peptide             ALWMRLLPL       1027381
# 2         FLFAVGFYL  Linear peptide             FLFAVGFYL       1007450
# 3         FLIVLSVAL  Linear peptide             FLIVLSVAL       1007450
# 4         FLWSVFMLI  Linear peptide             FLWSVFMLI       1007450
# 5        GIVEQCCTSI  Linear peptide            GIVEQCCTSI       1027381
# ..              ...             ...                   ...           ...
# 721      YLCNQDVAFL  Linear peptide            YLCNQDVAFL       1035280
# 722      YLQGQRLDNV  Linear peptide            YLQGQRLDNV       1035280
# 723       YMCTHRLLL  Linear peptide             YMCTHRLLL       1035280
# 724      YMCTHRLLLL  Linear peptide            YMCTHRLLLL       1035280
# 725       RLARLALVL  Linear peptide             RLARLALVL       1036010
#
#               reference_iri reference_type  ... r_object_source_organism_iri  \
# 0    IEDB_REFERENCE:1027381     Literature  ...                         None
# 2    IEDB_REFERENCE:1007450     Literature  ...                         None
# 3    IEDB_REFERENCE:1007450     Literature  ...                         None
# 4    IEDB_REFERENCE:1007450     Literature  ...                         None
# 5    IEDB_REFERENCE:1027381     Literature  ...                         None
# ..                      ...            ...  ...                          ...
# 721  IEDB_REFERENCE:1035280     Literature  ...                         None
# 722  IEDB_REFERENCE:1035280     Literature  ...                         None
# 723  IEDB_REFERENCE:1035280     Literature  ...                         None
# 724  IEDB_REFERENCE:1035280     Literature  ...                         None
# 725  IEDB_REFERENCE:1036010     Literature  ...                         None
#
#     r_object_source_organism_name e_related_object_type  \
# 0                            None                  None
# 2                            None                  None
# 3                            None                  None
# 4                            None                  None
# 5                            None                  None
# ..                            ...                   ...
# 721                          None                  None
# 722                          None                  None
# 723                          None                  None
# 724                          None                  None
# 725                          None                  None
#
#     curated_source_antigen.accession  \
# 0                        NP_000198.1
# 2                        NP_066999.1
# 3                           P10997.1
# 4                          SRC244406
# 5                         ABI63346.1
# ..                               ...
# 721                        550544195
# 722                         13529158
# 723                          3297877
# 724                          3297877
# 725                         Q13641.1
#
#                            curated_source_antigen.name  \
# 0                                 proinsulin precursor
# 2    islet-specific glucose-6-phosphatase-related p...
# 3                  Islet amyloid polypeptide precursor
# 4    islet-specific glucose-6-phosphatase-related p...
# 5                                              insulin
# ..                                                 ...
# 721  pyridoxal-dependent decarboxylase domain-conta...
# 722       Secretogranin V (7B2 protein) [Homo sapiens]
# 723                      GNAS1, partial [Homo sapiens]
# 724                      GNAS1, partial [Homo sapiens]
# 725                           Trophoblast glycoprotein
#
#     curated_source_antigen.iri curated_source_antigen.starting_position  \
# 0          GENPEPT:NP_000198.1                                      2.0
# 2          GENPEPT:NP_066999.1                                    215.0
# 3             GENPEPT:P10997.1                                      9.0
# 4                ONTIE:0002097                                      NaN
# 5           GENPEPT:ABI63346.1                                     78.0
# ..                         ...                                      ...
# 721          GENPEPT:550544195                                    189.0
# 722           GENPEPT:13529158                                    186.0
# 723            GENPEPT:3297877                                    379.0
# 724            GENPEPT:3297877                                    379.0
# 725           UNIPROT:Q13641.1                                     17.0
#
#     curated_source_antigen.ending_position  \
# 0                                     10.0
# 2                                    223.0
# 3                                     17.0
# 4                                      NaN
# 5                                     87.0
# ..                                     ...
# 721                                  198.0
# 722                                  195.0
# 723                                  387.0
# 724                                  388.0
# 725                                   25.0
#
#     curated_source_antigen.source_organism_name  \
# 0                          Homo sapiens (human)
# 2                          Homo sapiens (human)
# 3                          Homo sapiens (human)
# 4                          Homo sapiens (human)
# 5                          Homo sapiens (human)
# ..                                          ...
# 721                        Homo sapiens (human)
# 722                        Homo sapiens (human)
# 723                        Homo sapiens (human)
# 724                        Homo sapiens (human)
# 725                        Homo sapiens (human)
#
#     curated_source_antigen.source_organism_iri
# 0                               NCBITaxon:9606
# 2                               NCBITaxon:9606
# 3                               NCBITaxon:9606
# 4                               NCBITaxon:9606
# 5                               NCBITaxon:9606
# ..                                         ...
# 721                             NCBITaxon:9606
# 722                             NCBITaxon:9606
# 723                             NCBITaxon:9606
# 724                             NCBITaxon:9606
# 725                             NCBITaxon:9606
#
# [457 rows x 90 columns]

# %% [markdown]
# And there we go...the 457 unique epitope IDs we were after.  Note that we've lost some of the assay information by collapsing the data this way as the 'drop_duplicates' command will simply make the list unique according to the 'structure_iri'.  So if multiple assays have the same structure_iri, only the first one will be kept.  Depending on what we want to do with the data downstream, maybe this is OK, maybe we would want to collapse the data in another way, maybe we want to take those structure_iris and pull the corresponding records from the epitope_search table, or maybe something else entirely.
#
# Below we try to pull the corresponding structures from the epitope table, but we are running into technical issues that need to be worked out.  The recommendation would be do the initial query as above and then work with the dataset in your code.
#
# ### Pulling the corresponding structures from the epitope table - (not yet working)
#
# Let's try pulling the structure IRIs and recovering the corresponding epitopes from the epitope table as an example.  First, we collapse all the structure IRIs into a list and create the search string:

# %%
all_structure_iris = ','.join(map(str,df['structure_iri'].to_list()))
all_structure_iris_search =  'in.(' + all_structure_iris + ')'

# %% [markdown]
# Now we can search:

# %%
search_params={ 
                'structure_iri': all_structure_iris_search,
                #'structure_iri': 'in.(' + all_structure_iris + ')',
                'order': 'structure_iri',
              }
table_name='epitope_search'
full_url=base_uri + '/' + table_name
result = requests.get(full_url, params=search_params)
print_curl_cmd(result)
# Out:
# curl -X 'GET' 'https://query-api.iedb.org/epitope_search?structure_iri=in.%28IEDB_EPITOPE%3A100725%2CIEDB_EPITOPE%3A100725%2CIEDB_EPITOPE%3A100843%2CIEDB_EPITOPE%3A100844%2CIEDB_EPITOPE%3A100845%2CIEDB_EPITOPE%3A100882%2CIEDB_EPITOPE%3A100888%2CIEDB_EPITOPE%3A100920%2CIEDB_EPITOPE%3A100920%2CIEDB_EPITOPE%3A100920%2CIEDB_EPITOPE%3A100920%2CIEDB_EPITOPE%3A100920%2CIEDB_EPITOPE%3A100920%2CIEDB_EPITOPE%3A100920%2CIEDB_EPITOPE%3A100920%2CIEDB_EPITOPE%3A100920%2CIEDB_EPITOPE%3A100920%2CIEDB_EPITOPE%3A100920%2CIEDB_EPITOPE%3A100981%2CIEDB_EPITOPE%3A100981%2CIEDB_EPITOPE%3A100981%2CIEDB_EPITOPE%3A100981%2CIEDB_EPITOPE%3A101025%2CIEDB_EPITOPE%3A101026%2CIEDB_EPITOPE%3A101199%2CIEDB_EPITOPE%3A101199%2CIEDB_EPITOPE%3A101237%2CIEDB_EPITOPE%3A101245%2CIEDB_EPITOPE%3A101248%2CIEDB_EPITOPE%3A101248%2CIEDB_EPITOPE%3A101248%2CIEDB_EPITOPE%3A102306%2CIEDB_EPITOPE%3A102433%2CIEDB_EPITOPE%3A102515%2CIEDB_EPITOPE%3A102620%2CIEDB_EPITOPE%3A102769%2CIEDB_EPITOPE%3A102811%2CIEDB_EPITOPE%3A102844%2CIEDB_EPITOPE%3A102877%2CIEDB_EPITOPE%3A102877%2CIEDB_EPITOPE%3A102899%2CIEDB_EPITOPE%3A102899%2CIEDB_EPITOPE%3A102908%2CIEDB_EPITOPE%3A102908%2CIEDB_EPITOPE%3A102908%2CIEDB_EPITOPE%3A102908%2CIEDB_EPITOPE%3A103041%2CIEDB_EPITOPE%3A103041%2CIEDB_EPITOPE%3A103041%2CIEDB_EPITOPE%3A103041%2CIEDB_EPITOPE%3A103041%2CIEDB_EPITOPE%3A103368%2CIEDB_EPITOPE%3A103368%2CIEDB_EPITOPE%3A103557%2CIEDB_EPITOPE%3A103557%2CIEDB_EPITOPE%3A103557%2CIEDB_EPITOPE%3A103557%2CIEDB_EPITOPE%3A103557%2CIEDB_EPITOPE%3A103557%2CIEDB_EPITOPE%3A103557%2CIEDB_EPITOPE%3A103557%2CIEDB_EPITOPE%3A103557%2CIEDB_EPITOPE%3A103557%2CIEDB_EPITOPE%3A103705%2CIEDB_EPITOPE%3A103705%2CIEDB_EPITOPE%3A103705%2CIEDB_EPITOPE%3A103705%2CIEDB_EPITOPE%3A103705%2CIEDB_EPITOPE%3A103705%2CIEDB_EPITOPE%3A103705%2CIEDB_EPITOPE%3A103705%2CIEDB_EPITOPE%3A104248%2CIEDB_EPITOPE%3A104336%2CIEDB_EPITOPE%3A104336%2CIEDB_EPITOPE%3A104336%2CIEDB_EPITOPE%3A104336%2CIEDB_EPITOPE%3A104336%2CIEDB_EPITOPE%3A104767%2CIEDB_EPITOPE%3A104844%2CIEDB_EPITOPE%3A105674%2CIEDB_EPITOPE%3A106593%2CIEDB_EPITOPE%3A106609%2CIEDB_EPITOPE%3A106610%2CIEDB_EPITOPE%3A106611%2CIEDB_EPITOPE%3A1066141%2CIEDB_EPITOPE%3A1066141%2CIEDB_EPITOPE%3A1066141%2CIEDB_EPITOPE%3A1066583%2CIEDB_EPITOPE%3A1067282%2CIEDB_EPITOPE%3A1067282%2CIEDB_EPITOPE%3A1067642%2CIEDB_EPITOPE%3A1067642%2CIEDB_EPITOPE%3A1067654%2CIEDB_EPITOPE%3A1067709%2CIEDB_EPITOPE%3A1067709%2CIEDB_EPITOPE%3A1068341%2CIEDB_EPITOPE%3A1068341%2CIEDB_EPITOPE%3A1068410%2CIEDB_EPITOPE%3A1068511%2CIEDB_EPITOPE%3A1068511%2CIEDB_EPITOPE%3A1083942%2CIEDB_EPITOPE%3A1084399%2CIEDB_EPITOPE%3A1085428%2CIEDB_EPITOPE%3A1086925%2CIEDB_EPITOPE%3A10987%2CIEDB_EPITOPE%3A10987%2CIEDB_EPITOPE%3A10987%2CIEDB_EPITOPE%3A10987%2CIEDB_EPITOPE%3A10987%2CIEDB_EPITOPE%3A10987%2CIEDB_EPITOPE%3A10987%2CIEDB_EPITOPE%3A10987%2CIEDB_EPITOPE%3A10987%2CIEDB_EPITOPE%3A10987%2CIEDB_EPITOPE%3A10987%2CIEDB_EPITOPE%3A10987%2CIEDB_EPITOPE%3A10987%2CIEDB_EPITOPE%3A10987%2CIEDB_EPITOPE%3A10987%2CIEDB_EPITOPE%3A1100383%2CIEDB_EPITOPE%3A122422%2CIEDB_EPITOPE%3A122439%2CIEDB_EPITOPE%3A122439%2CIEDB_EPITOPE%3A122439%2CIEDB_EPITOPE%3A122439%2CIEDB_EPITOPE%3A1242282%2CIEDB_EPITOPE%3A1242558%2CIEDB_EPITOPE%3A1242580%2CIEDB_EPITOPE%3A1261064%2CIEDB_EPITOPE%3A12941%2CIEDB_EPITOPE%3A12941%2CIEDB_EPITOPE%3A12941%2CIEDB_EPITOPE%3A12941%2CIEDB_EPITOPE%3A12941%2CIEDB_EPITOPE%3A12941%2CIEDB_EPITOPE%3A12941%2CIEDB_EPITOPE%3A12941%2CIEDB_EPITOPE%3A12941%2CIEDB_EPITOPE%3A1310102%2CIEDB_EPITOPE%3A1310187%2CIEDB_EPITOPE%3A1310219%2CIEDB_EPITOPE%3A1311318%2CIEDB_EPITOPE%3A1311319%2CIEDB_EPITOPE%3A1311321%2CIEDB_EPITOPE%3A1311337%2CIEDB_EPITOPE%3A1311340%2CIEDB_EPITOPE%3A1311362%2CIEDB_EPITOPE%3A1311369%2CIEDB_EPITOPE%3A1311384%2CIEDB_EPITOPE%3A1311385%2CIEDB_EPITOPE%3A1311396%2CIEDB_EPITOPE%3A1311398%2CIEDB_EPITOPE%3A1311401%2CIEDB_EPITOPE%3A1311497%2CIEDB_EPITOPE%3A1311498%2CIEDB_EPITOPE%3A1311511%2CIEDB_EPITOPE%3A1311518%2CIEDB_EPITOPE%3A1311526%2CIEDB_EPITOPE%3A1312163%2CIEDB_EPITOPE%3A131311%2CIEDB_EPITOPE%3A1313691%2CIEDB_EPITOPE%3A131878%2CIEDB_EPITOPE ...

# %%
print(json.dumps(result.json()[:1], indent=4))
#df = pd.json_normalize(result.json())
#df
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-10-1f97b389c2de> in <module>
# ----> 1 print(json.dumps(result.json()[:1], indent=4))
#       2 #df = pd.json_normalize(result.json())
#       3 #df
#
# ~/.pyenv/versions/3.8.2/envs/jupyter/lib/python3.8/site-packages/requests/models.py in json(self, **kwargs)
#     898                     # used.
#     899                     pass
# --> 900         return complexjson.loads(self.text, **kwargs)
#     901
#     902     @property
#
# ~/.pyenv/versions/3.8.2/lib/python3.8/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     355             parse_int is None and parse_float is None and
#     356             parse_constant is None and object_pairs_hook is None and not kw):
# --> 357         return _default_decoder.decode(s)
#     358     if cls is None:
#     359         cls = JSONDecoder
#
# ~/.pyenv/versions/3.8.2/lib/python3.8/json/decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ~/.pyenv/versions/3.8.2/lib/python3.8/json/decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %% [markdown]
# Hmmm...OK it looks like the string of IDs is too long and we're getting gatweay errors.  I'm not sure if this issue is at the web server or PostgresT level, but we will investigate.  It should also be noted that we could be doing better error/exception handling when we call the API.  We'll add a tutorial on that in the near future.
