# %% [markdown]
# # Summarize epitopes by antigen
#
# Given a list of pubmed IDs, use the IQ-API to pull in all antigen and epitope information
# and summarize as follows:
#
# * antigen_id, name, etc.
# * number of reference that report positive epitopes derived from that antigen
# * total num_peptides_positive derived from each antigen (each peptide is counted only once even if it appears in multiple references)

# %%
import warnings
warnings.filterwarnings('ignore')

import os
import io
import time
import requests
import pandas as pd

# %%
# Read in the pubmed IDs from a file:
with open('pubmed_ids.txt') as f:
    pubmed_ids = [i.rstrip() for i in f.readlines()]
    pubmed_id_string = ','.join(pubmed_ids)

# %% [markdown]
# Let's define a function for running a query and returning a dataframe of results.  Since there may be more than 10K records, we will need to fetch 1 page at a time and continue to append them onto our dataframe.
#
# **NOTE:** When paging through results by using an 'offset', it is critical to add an 'order' parameter to ensure that the pages are consistent between queries.
#
# To be good citizens, we also add a short 'sleep' in between calls to the API.

# %%
def iq_query(endpoint, query_params, base_uri='https://query-api.iedb.org/'):

    url = os.path.join(base_uri, endpoint)
    df = pd.DataFrame()
    
    # set the offset to 0
    query_params['offset'] = 0
    
    # loop through the pages of results
    # API only allows pulling 10,000 entries at a time
    while(True):
        print('Fetching offset: %i' % query_params['offset'])
        r = requests.get(url, params=query_params, headers={'accept': 'text/csv', 'Prefer': 'count=exact'})
        try:
            df = pd.concat([df, pd.read_csv(io.StringIO(r.content.decode('utf-8')))])
            query_params['offset'] += 10000
        except pd.errors.EmptyDataError:
            break
        
        # sleep for 1 second between calls so as not to overload the server
        time.sleep(1)
    
    return df

# %% [markdown]
# ### Map the pubmed IDs to reference IDs
#
# Let's set the query string parameters

# %%
query_params = {'pubmed_id': 'in.(%s)' % pubmed_id_string,
                'order': 'pubmed_id',
                'select': 'pubmed_id,reference_id'}

# %% [markdown]
# And pull the data and create a reference ID string to incorporate into downstream queries:

# %%
ref2pmid = iq_query('reference_search', query_params)
ref_id_string = ','.join(list(ref2pmid['reference_id'].astype(str)))
# Out:
# Fetching offset: 0
# Fetching offset: 10000

# %% [markdown]
# ### Fetch the positive T & B cell epitopes
# First, set the query parameters:

# %%
query_params = {'reference_id': 'in.(%s)' % ref_id_string,
                'qualitative_measure': 'neq.Negative',
                'order': 'pubmed_id',
                'select': 'reference_id,parent_source_antigen_iri,structure_id,structure_description,curated_source_antigen'}

# %% [markdown]
# Now run the query against tcell_search

# %%
tcell_epitopes = iq_query('tcell_search', query_params)
# Out:
# Fetching offset: 0
# Fetching offset: 10000

# %% [markdown]
# And then B cell search:

# %%
bcell_epitopes = iq_query('bcell_search', query_params)
# Out:
# Fetching offset: 0
# Fetching offset: 10000

# %% [markdown]
# **NOTE** There are certain cases when the source antigen is unknown/null.  We'll quantify
# those here, but will ignore those epitopes for the remainder of this analysis.
#
# ### Initial summary
#
# Here we summarize the number of T & B cell epitopes retrieved and the number where the source antigen (parent protein) is not null.  We move forward by combining these data.

# %%
# "~" operator is NOT; remove epitopes without a source antigen
tcell_epitopes = tcell_epitopes[~tcell_epitopes['parent_source_antigen_iri'].isna()]
bcell_epitopes = bcell_epitopes[~bcell_epitopes['parent_source_antigen_iri'].isna()]

# %% [markdown]
# In both cases, more so in B cell, there are many records that are not mapped to a parent protein.  We'll investigate down below.
#
# Let's combine all epitopes into one dataframe.

# %%
all_epitopes = pd.concat([tcell_epitopes, bcell_epitopes])

# %% [markdown]
# ### References and peptides per parent antigen
#
# Let's get the number of references and peptides (including discontinuous sequences) per parent antigen for each parent antigen first.

# %%
ref_data  = []
peps_data = []
for i, row in all_epitopes.groupby('parent_source_antigen_iri'):
    ref_data.append([i, len(row['reference_id'].unique())])
    peps_data.append([i, len(row['structure_id'].unique())])

refs_per_parent_antigen = pd.DataFrame(data=ref_data, columns=['parent_source_antigen_iri', 'num_references'])
peps_per_parent_antigen = pd.DataFrame(data=peps_data, columns=['parent_source_antigen_iri', 'num_peptides'])

# %%
refs_per_parent_antigen
# Out:
#    parent_source_antigen_iri  num_references
# 0             UNIPROT:A2JGV3               1
# 1             UNIPROT:A5PLL7               3
# 2             UNIPROT:I3L0A0               1
# 3             UNIPROT:O15438               2
# 4             UNIPROT:O15466               1
# 5             UNIPROT:O42043               1
# 6             UNIPROT:O75638               1
# 7             UNIPROT:P00533               2
# 8             UNIPROT:P02782               1
# 9             UNIPROT:P06239               3
# 10            UNIPROT:P07288               3
# 11            UNIPROT:P08183               1
# 12            UNIPROT:P0DTU4               1
# 13            UNIPROT:P12272               2
# 14            UNIPROT:P14866               3
# 15            UNIPROT:P15309               3
# 16            UNIPROT:P20151               2
# 17            UNIPROT:P22732               1
# 18            UNIPROT:P23284               3
# 19            UNIPROT:P60484               1
# 20            UNIPROT:P62684               1
# 21            UNIPROT:P63145               1
# 22            UNIPROT:P78358               1
# 23            UNIPROT:Q04609               2
# 24            UNIPROT:Q13541               1
# 25            UNIPROT:Q15020               4
# 26            UNIPROT:Q15910               1
# 27            UNIPROT:Q16655               1
# 28            UNIPROT:Q96JT2               1
# 29            UNIPROT:Q9BZD4               1
# 30            UNIPROT:Q9H3P2               3
# 31            UNIPROT:Q9N2K0               1
# 32            UNIPROT:Q9NRP7               1
# 33            UNIPROT:Q9UL01               1
# 34            UNIPROT:Q9UQF0               1
# 35            UNIPROT:Q9Y3S1               2
# 36            UNIPROT:Q9Y572               1
# 37     taxon_protein:9606-ab               1

# %% [markdown]
# ### Source antigen (parent protein) data
#
# Before we put everything together, we need to pull all of the source antigen information.  Since the parent_source_antigen_iri is not yet in the parent_proteins table, we first pull ALL of the parent proteins
# and create the parent_source_antigen_uri later.

# %%
query_params = {'order': 'accession',
                'select': 'database,accession,name,title,proteome_label'}

# %% [markdown]
# Now run the query against parent_proteins to pull everything out

# %%
parent_proteins = iq_query('parent_proteins', query_params)
# Out:
# Fetching offset: 0
# Fetching offset: 10000
# Fetching offset: 20000
# Fetching offset: 30000
# Fetching offset: 40000
# Fetching offset: 50000
# Fetching offset: 60000
# Fetching offset: 70000
# Fetching offset: 80000
# Fetching offset: 90000
# Fetching offset: 100000

# %%
# let's add a psuedo parent_source_antigen_iri
parent_proteins['parent_source_antigen_iri'] = parent_proteins['database'].str.upper() + ':' + parent_proteins['accession'].str[:]

# %% [markdown]
# ### Final summary by parent protein
#
# Here, we combine the data into the table of interest

# %%
final_summary_by_parent = pd.merge(refs_per_parent_antigen, peps_per_parent_antigen, how='left', on='parent_source_antigen_iri')
final_summary_by_parent = pd.merge(final_summary_by_parent, parent_proteins, how='left', on='parent_source_antigen_iri')

# rename some columns
final_summary_by_parent.rename(columns={'parent_source_antigen_iri': 'antigen_id',
                                        'title': 'antigen_title'}, inplace=True)

# sort by number of references and number of peptides
final_summary_by_parent = final_summary_by_parent.sort_values('num_references', ascending=False)
final_summary_by_parent = final_summary_by_parent.sort_values('num_peptides', ascending=False)

final_summary_by_parent
# Out:
#                antigen_id  num_references  num_peptides database accession  \
# 25         UNIPROT:Q15020               4             8  UniProt    Q15020
# 13         UNIPROT:P12272               2             8  UniProt    P12272
# 9          UNIPROT:P06239               3             7  UniProt    P06239
# 17         UNIPROT:P22732               1             7  UniProt    P22732
# 21         UNIPROT:P63145               1             6  UniProt    P63145
# 20         UNIPROT:P62684               1             6  UniProt    P62684
# 10         UNIPROT:P07288               3             6  UniProt    P07288
# 19         UNIPROT:P60484               1             5  UniProt    P60484
# 23         UNIPROT:Q04609               2             4  UniProt    Q04609
# 8          UNIPROT:P02782               1             4  UniProt    P02782
# 15         UNIPROT:P15309               3             4  UniProt    P15309
# 22         UNIPROT:P78358               1             3  UniProt    P78358
# 1          UNIPROT:A5PLL7               3             3  UniProt    A5PLL7
# 28         UNIPROT:Q96JT2               1             3  UniProt    Q96JT2
# 6          UNIPROT:O75638               1             3  UniProt    O75638
# 14         UNIPROT:P14866               3             2  UniProt    P14866
# 30         UNIPROT:Q9H3P2               3             2  UniProt    Q9H3P2
# 0          UNIPROT:A2JGV3               1             2      NaN       NaN
# 11         UNIPROT:P08183               1             2  UniProt    P08183
# 34         UNIPROT:Q9UQF0               1             2  UniProt    Q9UQF0
# 33         UNIPROT:Q9UL01               1             2  UniProt    Q9UL01
# 5          UNIPROT:O42043               1             2  UniProt    O42043
# 3          UNIPROT:O15438               2             2  UniProt    O15438
# 35         UNIPROT:Q9Y3S1               2             2  UniProt    Q9Y3S1
# 4          UNIPROT:O15466               1             2  UniProt    O15466
# 18         UNIPROT:P23284               3             2  UniProt    P23284
# 31         UNIPROT:Q9N2K0               1             2  UniProt    Q9N2K0
# 12         UNIPROT:P0DTU4               1             1  UniProt    P0DTU4
# 2          UNIPROT:I3L0A0               1             1  UniProt    I3L0A0
# 36         UNIPROT:Q9Y572               1             1  UniProt    Q9Y572
# 24         UNIPROT:Q13541               1             1  UniProt    Q13541
# 26         UNIPROT:Q15910               1             1  UniProt    Q15910
# 27         UNIPROT:Q16655               1             1  UniProt    Q16655
# 29         UNIPROT:Q9BZD4               1             1  UniProt    Q9BZD4
# 32         UNIPROT:Q9NRP7               1             1  UniProt    Q9NRP7
# 7          UNIPROT:P00533               2             1  UniProt    P00533
# 16         UNIPROT:P20151               2             1  UniProt    P20151
# 37  taxon_protein:9606-ab               1             1      NaN       NaN
#
#                       name                                      antigen_title  \
# 25   sp|Q15020|SART3_HUMAN  Squamous cell carcinoma antigen recognized by ...
# 13    sp|P12272|PTHR_HUMAN                Parathyroid hormone-related protein
# 9      sp|P06239|LCK_HUMAN                        Tyrosine-protein kinase Lck
# 17    sp|P22732|GTR5_HUMAN  Solute carrier family 2, facilitated glucose t...
# 21   sp|P63145|GAK24_HUMAN  Endogenous retrovirus group K member 24 Gag po...
# 20   sp|P62684|GA113_HUMAN  Endogenous retrovirus group K member 113 Gag p...
# 10    sp|P07288|KLK3_HUMAN                          Prostate-specific antigen
# 19    sp|P60484|PTEN_HUMAN  Phosphatidylinositol 3,4,5-trisphosphate 3-pho...
# 23   sp|Q04609|FOLH1_HUMAN                       Glutamate carboxypeptidase 2
# 8       sp|P02782|PSC1_RAT               Prostatic steroid-binding protein C1
# 15    sp|P15309|PPAP_HUMAN                         Prostatic acid phosphatase
# 22   sp|P78358|CTG1B_HUMAN                            Cancer/testis antigen 1
# 1    sp|A5PLL7|PDES1_HUMAN                   Plasmanylethanolamine desaturase
# 28   sp|Q96JT2|S45A3_HUMAN                  Solute carrier family 45 member 3
# 6    sp|O75638|CTAG2_HUMAN                            Cancer/testis antigen 2
# 14   sp|P14866|HNRPL_HUMAN          Heterogeneous nuclear ribonucleoprotein L
# 30   sp|Q9H3P2|NELFA_HUMAN                       Negative elongation factor A
# 0                      NaN                                                NaN
# 11    sp|P08183|MDR1_HUMAN                    ATP-dependent translocase ABCB1
# 34   sp|Q9UQF0|SYCY1_HUMAN                                         Syncytin-1
# 33     sp|Q9UL01|DSE_HUMAN                         Dermatan-sulfate epimerase
# 5    sp|O42043|ENK18_HUMAN  Endogenous retrovirus group K member 18 Env po...
# 3     sp|O15438|MRP3_HUMAN         ATP-binding cassette sub-family C member 3
# 35    sp|Q9Y3S1|WNK2_HUMAN               Serine/threonine-protein kinase WNK2
# 4    sp|O15466|SIA8E_HUMAN                     Alpha-2,8-sialyltransferase 8E
# 18    sp|P23284|PPIB_HUMAN              Peptidyl-prolyl cis-trans isomerase B
# 31    sp|Q9N2K0|ENH1_HUMAN   HERV-H_2q24.3 provirus ancestral Env polyprotein
# 12   sp|P0DTU4|TRBR2_HUMAN                 T cell receptor beta chain MC.7.G5
# 2   tr|I3L0A0|I3L0A0_HUMAN                                         HCG2044781
# 36   sp|Q9Y572|RIPK3_HUMAN  Receptor-interacting serine/threonine-protein ...
# 24   sp|Q13541|4EBP1_HUMAN  Eukaryotic translation initiation factor 4E-bi...
# 26    sp|Q15910|EZH2_HUMAN            Histone-lysine N-methyltransferase EZH2
# 27    sp|Q16655|MAR1_HUMAN           Melanoma antigen recognized by T-cells 1
# 29    sp|Q9BZD4|NUF2_HUMAN                           Kinetochore protein Nuf2
# 32   sp|Q9NRP7|STK36_HUMAN                 Serine/threonine-protein kinase 36
# 7     sp|P00533|EGFR_HUMAN                   Epidermal growth factor receptor
# 16    sp|P20151|KLK2_HUMAN                                       Kallikrein-2
# 37                     NaN                                                NaN
#
#                                     proteome_label
# 25                            Homo sapiens (Human)
# 13                            Homo sapiens (Human)
# 9                             Homo sapiens (Human)
# 17                            Homo sapiens (Human)
# 21                            Homo sapiens (Human)
# 20                            Homo sapiens (Human)
# 10                            Homo sapiens (Human)
# 19                            Homo sapiens (Human)
# 23                            Homo sapiens (Human)
# 8   Rattus norvegicus (Rat) (Strain: Brown Norway)
# 15                            Homo sapiens (Human)
# 22                            Homo sapiens (Human)
# 1                             Homo sapiens (Human)
# 28                            Homo sapiens (Human)
# 6                             Homo sapiens (Human)
# 14                            Homo sapiens (Human)
# 30                            Homo sapiens (Human)
# 0                                              NaN
# 11                            Homo sapiens (Human)
# 34                            Homo sapiens (Human)
# 33                            Homo sapiens (Human)
# 5                             Homo sapiens (Human)
# 3                             Homo sapiens (Human)
# 35                            Homo sapiens (Human)
# 4                             Homo sapiens (Human)
# 18                            Homo sapiens (Human)
# 31                            Homo sapiens (Human)
# 12                            Homo sapiens (Human)
# 2                             Homo sapiens (Human)
# 36                            Homo sapiens (Human)
# 24                            Homo sapiens (Human)
# 26                            Homo sapiens (Human)
# 27                            Homo sapiens (Human)
# 29                            Homo sapiens (Human)
# 32                            Homo sapiens (Human)
# 7                             Homo sapiens (Human)
# 16                            Homo sapiens (Human)
# 37                                             NaN

# %% [markdown]
# As we can see by the row with an empty antigen_id & antigen_title, there are a good number of proteins that are not mapped to a parent protein.  So let's have a closer look at those, specifically:

# %%
all_epitopes['curated_antigen_accession'] = all_epitopes['curated_source_antigen'].str.split(',').str[0].str[1:]
all_epitopes[all_epitopes['parent_source_antigen_iri'].isna()]
# Out:
# Empty DataFrame
# Columns: [reference_id, parent_source_antigen_iri, structure_id, structure_description, curated_source_antigen, curated_antigen_accession]
# Index: []

# %% [markdown]
# Interesting!  None of them have curated source antigens, so we should investigate why and ignore them if there is a good explanation.
